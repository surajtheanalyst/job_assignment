# %%
import pandas as pd

# %% [markdown]
#  loading the dataset into a pandas DataFrame

# %%
df = pd.read_csv(r"C:\Users\suraj\Desktop\Chakr Innovation Assignment\Assignment - Junior Data Analyst.csv")

# %%
df.head(5)
# Out:
#             battery                                     camera  \
# 0  5000 mAh Battery              12MP + 2MP | 8MP Front Camera
# 1  5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 2  5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 3  5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 4  4000 mAh Battery              13MP + 2MP | 5MP Front Camera
#
#                             display  \
# 0   15.8 cm (6.22 inch) HD+ Display
# 1  16.56 cm (6.52 inch) HD+ Display
# 2  16.56 cm (6.52 inch) HD+ Display
# 3  16.56 cm (6.52 inch) HD+ Display
# 4   15.49 cm (6.1 inch) HD+ Display
#
#                                           memory  \
# 0  4 GB RAM | 64 GB ROM | Expandable Upto 512 GB
# 1                           4 GB RAM | 64 GB ROM
# 2                          4 GB RAM | 128 GB ROM
# 3                          4 GB RAM | 128 GB ROM
# 4  3 GB RAM | 32 GB ROM | Expandable Upto 256 GB
#
#                                name  price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   battery    984 non-null    object
#  1   camera     984 non-null    object
#  2   display    984 non-null    object
#  3   memory     984 non-null    object
#  4   name       984 non-null    object
#  5   price      984 non-null    int64
#  6   processor  983 non-null    object
#  7   rating     971 non-null    float64
#  8   reviews    971 non-null    object
#  9   warranty   836 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 77.0+ KB

# %%
df.describe()
# Out:
#                price      rating
# count     984.000000  971.000000
# mean    15429.848577    4.241195
# std     12891.355967    0.300296
# min       887.000000    2.700000
# 25%      7499.000000    4.100000
# 50%     11649.000000    4.300000
# 75%     17999.250000    4.400000
# max    104999.000000    4.900000

# %%
df.columns
# Out:
# Index(['battery', 'camera', 'display', 'memory', 'name', 'price', 'processor',
#        'rating', 'reviews', 'warranty'],
#       dtype='object')

# %%
df["name"].value_counts().head(20)
# Out:
# name
# Realme C2 (Diamond Blue, 32 GB)                   4
# Realme C2 (Diamond Black, 32 GB)                  4
# Redmi 8 (Ruby Red, 64 GB)                         2
# Realme X (Space Blue, 128 GB)                     2
# Asus Zenfone Max Pro M1 (Blue, 64 GB)             2
# Redmi 8A (Sunset Red, 32 GB)                      2
# Realme 2 Pro (Blue Ocean, 64 GB)                  2
# Realme X3 (Glacier Blue, 128 GB)                  2
# Nokia 7.2 (Cyan Green, 64 GB)                     2
# Samsung Galaxy A21s (Blue, 64 GB)                 2
# Samsung Galaxy A21s (Black, 64 GB)                2
# OPPO A5s (Black, 32 GB)                           2
# OPPO F15 (Unicorn White, 128 GB)                  2
# Samsung Galaxy A51 (Prism Crush Black, 128 GB)    2
# Honor 9X (Midnight Black, 128 GB)                 2
# Realme X2 (Pearl White, 128 GB)                   2
# Vivo Z1Pro (Sonic Black, 64 GB)                   2
# Redmi 8A Dual (Midnight Grey, 32 GB)              2
# ...

# %%
df["processor"].value_counts().head(20)
# Out:
# processor
# Qualcomm Snapdragon 730G Processor                                                                                                                 21
# 1 year manufacturer warranty for device and 6 months manufacturer warranty for in-box accessories including batteries from the date of purchase    20
# Qualcomm Snapdragon 439 Processor                                                                                                                  18
# MediaTek Helio G90T Processor                                                                                                                      18
# Qualcomm Snapdragon 665 Processor                                                                                                                  18
# 1 Year Manufacturer Warranty                                                                                                                       16
# ...

# %%
df["display"].value_counts().head(20)
# Out:
# display
# 16.0 cm (6.3 inch) Full HD+ Display      56
# 12.7 cm (5 inch) HD Display              52
# 15.8 cm (6.22 inch) HD+ Display          48
# 16.26 cm (6.4 inch) Full HD+ Display     45
# 16.59 cm (6.53 inch) Full HD+ Display    36
# 16.51 cm (6.5 inch) Full HD+ Display     31
# 13.84 cm (5.45 inch) HD+ Display         29
# 15.75 cm (6.2 inch) HD+ Display          28
# 16.51 cm (6.5 inch) HD+ Display          25
# 17.02 cm (6.7 inch) Full HD+ Display     21
# 16.56 cm (6.52 inch) HD+ Display         21
# 16.26 cm (6.4 inch) Display              20
# 16.94 cm (6.67 inch) Full HD+ Display    20
# 15.49 cm (6.1 inch) HD+ Display          17
# 12.7 cm (5 inch) FWVGA Display           15
# 15.21 cm (5.99 inch) Full HD+ Display    15
# 15.9 cm (6.26 inch) HD+ Display          15
# 13.97 cm (5.5 inch) Full HD Display      15
# 16.36 cm (6.44 inch) Full HD+ Display    14
# 16.23 cm (6.39 inch) Full HD+ Display    14
# Name: count, dtype: int64

# %%
df["memory"].value_counts().head(20)
# Out:
# memory
# 4 GB RAM | 64 GB ROM | Expandable Upto 256 GB     88
# 3 GB RAM | 32 GB ROM | Expandable Upto 256 GB     63
# 4 GB RAM | 64 GB ROM | Expandable Upto 512 GB     42
# 6 GB RAM | 128 GB ROM | Expandable Upto 256 GB    41
# 8 GB RAM | 128 GB ROM                             39
# 3 GB RAM | 32 GB ROM | Expandable Upto 128 GB     36
# 6 GB RAM | 128 GB ROM                             36
# 6 GB RAM | 128 GB ROM | Expandable Upto 512 GB    35
# 4 GB RAM | 64 GB ROM                              34
# 1 GB RAM | 8 GB ROM | Expandable Upto 32 GB       34
# 6 GB RAM | 64 GB ROM | Expandable Upto 256 GB     31
# 8 GB RAM | 128 GB ROM | Expandable Upto 256 GB    27
# 3 GB RAM | 32 GB ROM | Expandable Upto 512 GB     24
# 2 GB RAM | 16 GB ROM                              24
# 8 GB RAM | 256 GB ROM                             20
# 3 GB RAM | 32 GB ROM                              20
# 2 GB RAM | 16 GB ROM | Expandable Upto 128 GB     20
# 8 GB RAM | 128 GB ROM | Expandable Upto 512 GB    19
# ...

# %%
import matplotlib.pyplot as plt

# %%
df["battery"].hist(bins = 15)
plt.title("BATTERY DISTRIBUTION")
plt.xlabel("Battery")
plt.ylabel("Frequency")
plt.show()

# %%
df["camera"].hist(bins = 15)
plt.title("CAMERA DISTRIBUTION")
plt.xlabel("CAMERA")
plt.ylabel("Frequency")
plt.show()

# %%
df["display"].hist(bins = 15)
plt.title("DISPLAY DISTRIBUTION")
plt.xlabel("dISPLAY")
plt.ylabel("Frequency")
plt.show()

# %%
df["memory"].hist(bins = 15)
plt.title("MEMORY DISTRIBUTION")
plt.xlabel("Memory")
plt.ylabel("Frequency")
plt.show()

# %%
df["price"].hist(bins = 15)
plt.title("PRICE DISTRIBUTION")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
df["rating"].hist(bins = 15)
plt.title("RATING DISTRIBUTION")
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.show()

# %%
import seaborn as sns

# %%
sns.boxenplot(data = df, x = "price")
plt.title("Price Distribution")
plt.show()

# %%
sns.boxenplot(data = df, x = "rating")
plt.title("Rating Distribution")
plt.show()

# %%
correlation_matrix = df[['battery', 'camera', 'display', 'memory', 'price', 'rating', 'reviews']].corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 correlation_matrix = df[['battery', 'camera', 'display', 'memory', 'price', 'rating', 'reviews']].corr()
#       2 sns.heatmap(correlation_matrix, annot=True)
#       3 plt.title('Correlation Matrix')
#
# File c:\Users\suraj\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\suraj\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
# ...

# %%
print(df.dtypes)
print(df[['battery', 'camera', 'display', 'memory']].head())
# Out:
# battery       object
# camera        object
# display       object
# memory        object
# name          object
# price          int64
# processor     object
# rating       float64
# reviews       object
# warranty      object
# dtype: object
#             battery                                     camera  \
# 0  5000 mAh Battery              12MP + 2MP | 8MP Front Camera
# 1  5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 2  5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 3  5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 4  4000 mAh Battery              13MP + 2MP | 5MP Front Camera
#
#                             display  \
# 0   15.8 cm (6.22 inch) HD+ Display
# 1  16.56 cm (6.52 inch) HD+ Display
# 2  16.56 cm (6.52 inch) HD+ Display
# 3  16.56 cm (6.52 inch) HD+ Display
# 4   15.49 cm (6.1 inch) HD+ Display
#
#                                           memory
# 0  4 GB RAM | 64 GB ROM | Expandable Upto 512 GB
# ...

# %%
df['battery'] = df['battery'].str.replace(' mAh Battery', '', "mAh Li-ion Polymer Battery", "").astype(float)

# %%
correlation_matrix = df[['battery',  'price', 'rating']].corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix')
plt.show()

# %%
sns.scatterplot(x='battery', y='price', data=df)
plt.title('Battery vs Price')
plt.show()
